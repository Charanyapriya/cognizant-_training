# %%
name="charanya priya"
print(name)
# Out:
# charanya priya

# %%
scores=[60,70,45,67,89,90]
print(scores)
# Out:
# [60, 70, 45, 67, 89, 90]

# %%
print(scores[1])
# Out:
# 70

# %%
print(scores[4])
# Out:
# 89

# %%
print(scores[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(scores[6])
#
# IndexError: list index out of range
