# %%
name="charanya"
print(name)
# Out:
# charanya

# %%
class Person:
    def __init__(self,age,course):
      self.age = age
      self.course = course
p1 = Person(20,"data science")
print(p1.course)
# Out:
# data science

# %%
class Mobile:
    def __init__(self,name,brand):
      self.name = name
      self.brand = brand
m1=Mobile ("iphone pro max","orange")
print(m1.name)
print(m1.brand)
# Out:
# iphone pro max
# orange

# %%
name= "charanya"
print(name[2])
# Out:
# a

# %%
name ="charanya"
print(name[1:6])
# Out:
# haran

# %%
name= "charanya"
print(name[-5])
# Out:
# r

# %%
s = "hello"
print("hello" *4)
# Out:
# hellohellohellohello

# %%
chocolate = "kitkat"
print("kitkat" *3)
# Out:
# kitkatkitkatkitkat

# %%
name="charanya priya"
print(name.upper())
# Out:
# CHARANYA PRIYA

# %%
name="NAVADEEP"
print(name.lower())
# Out:
# navadeep

# %%
S="i Like java"
print(S.replace("java","python"))
# Out:
# i Like python

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("enter the name :")
print("welcome",name)
# Out:
# enter the name : charanya
# welcome charanya

# %%
name = input("enter the name :")

fee=input("enter the fee :")
course=input("enter the course :")
print("succesful",name)
print("succesful",course)
# Out:
# enter the name : priya
# enter the fee : 2000
# enter the course : data science
# succesful priya
# succesful data science

# %%
p="python"
print(p[::-1])
# Out:
# nohtyp

# %%
s="succesful"
print(s[::-2])
# Out:
# lfecs

# %%
name="charanya"
def greet():
    print("hello" , name)
greet()
# Out:
# hello charanya

# %%
name="cherry"
def succesful():
    print("motivator" , name)
succesful()
# Out:
# motivator cherry

# %%
def add(a,b):
    return a+b
print(add(10,20))
# Out:
# 30

# %%
def add(a,b,c=0):
    return a+b
print(add(10,20))
print(add(10,20,30))
# Out:
# 30
# 30

# %%
def mul(a,b):
    return a*b
print(mul(10,30))
# Out:
# 300

# %%
def mul(a,b,c=0):
    return a*b*c
print(mul(2,4))
print(mul(4,5))
# Out:
# 0
# 0

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def student(*marks):
    print(sum(marks))
student(85,60)
student(50,60,78)
student(55,90,98)
# Out:
# 145
# 188
# 243
