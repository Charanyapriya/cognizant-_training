# %%
name = ["charanya","cherry","priya"]
it= iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# charanya
# cherry
# priya

# %%
s=[100,28,56,78,97,67]
it= iter(s)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 100
# 28
# 56
# 78
# 97

# %%
s=("berry","tommy")
print(s)
# Out:
# ('berry', 'tommy')

# %%
s=["berry","tommy"]
print(s)
# Out:
# ['berry', 'tommy']

# %%
s=["berry","tommy"]
it= iter(s)
print(next(it))
print(next(it))
# Out:
# berry
# tommy

# %%
file = open("demo.txt","w")
file.write("hello")
file.close()
file = open("demo.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hello

# %%
list = [12,32,45,65,76]
print(list[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 list = [12,32,45,65,76]
# ----> 2 print(list[6])
#
# IndexError: list index out of range

# %%
list = [12,32,45,65,76]
print(list[2])
# Out:
# 45

# %%
num = 10
print(num/0)
print("last line of the program")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 num = 10
# ----> 2 print(num/0)
#       3 print("last line of the program")
#
# ZeroDivisionError: division by zero

# %%
try:
    num = 10
    print(num/0)
except ZeroDivisionError:
      print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
  file = open("xyz.txt","r")
except FileNotFoundError:
  print("file not found")
# Out:
# file not found

# %%
try:
    age =  int(input("enter your age"))
except FileNotFoundError:
    print("enter the valid age")
# Out:
# enter your age 20
